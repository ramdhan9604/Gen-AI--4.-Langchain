# %% [markdown]
# <span style="color: red; font-size: 30px; font-weight: bold; background-color: yellow;">
# 1. Install All the Required Packages
# </span>

# %%
# !pip install langchain langchain_community
# !pip install huggingface_hub 
# !pip install transformers 
# !pip install accelerate
# !pip install bitsandbytes
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 40.3 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 45.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 414.3/414.3 kB 23.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: async-timeout
#     Found existing installation: async-timeout 5.0.1
#     Uninstalling async-timeout-5.0.1:
#       Successfully uninstalled async-timeout-5.0.1
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.25
#     Uninstalling langchain-core-0.3.25:
#       Successfully uninstalled langchain-core-0.3.25
#   Attempting uninstall: langchain-text-splitters
#     Found existing installation: langchain-text-splitters 0.3.3
#     Uninstalling langchain-text-splitters-0.3.3:
#       Successfully uninstalled langchain-text-splitters-0.3.3
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.12
#     Uninstalling langchain-0.3.12:
# ...

# %% [markdown]
# <span style="color: red; font-size: 30px; font-weight: bold; background-color: yellow;">
# 2. Import All the Required Libraries
# </span>

# %%
from langchain import PromptTemplate, HuggingFaceHub, LLMChain 
import os

# %% [markdown]
# <span style="color: red; font-size: 30px; font-weight: bold; background-color: yellow;">
# 3. Setting the Environment
# </span>

# %%
os.environ['HUGGINGFACEHUB_API_TOKEN'] = "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"

# %% [markdown]
# <span style="color: red; font-size: 30px; font-weight: bold; background-color: yellow;">
# 4.Approach 1: Access Models Hosted on Hugging Face Through API
#
#     Text2Text Generation Models | Seq2Seq Models | Encoder-Decoder Models
# </span>

# %%
prompt = PromptTemplate(
    input_variables=["product"],
    template="What is a good name for a company that makes {product}"
)

# %%
chain = LLMChain(llm=HuggingFaceHub(repo_id='google/flan-t5-large', model_kwargs={'temperature':0, 'max_length':64}),prompt = prompt)
# Out:
# <ipython-input-5-413b1ae71a85>:1: LangChainDeprecationWarning: The class `HuggingFaceHub` was deprecated in LangChain 0.0.21 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEndpoint``.
#   chain = LLMChain(llm=HuggingFaceHub(repo_id='google/flan-t5-large', model_kwargs={'temperature':0, 'max_length':64}),prompt = prompt)
# <ipython-input-5-413b1ae71a85>:1: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   chain = LLMChain(llm=HuggingFaceHub(repo_id='google/flan-t5-large', model_kwargs={'temperature':0, 'max_length':64}),prompt = prompt)

# %%
chain.run("colorful socks")
# Out:
# <ipython-input-6-50b28d707c1c>:1: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   chain.run("colorful socks")
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
# 'sock mania'

# %%
prompt = PromptTemplate(
    input_variables=["name"],
    template="Can you tell me about famous footballer {name}"
)

# %%
chain = LLMChain(llm=HuggingFaceHub(repo_id='google/flan-t5-large', model_kwargs={'temperature':0, 'max_length':64}),prompt = prompt)

# %%
chain.run("Messi")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
# 'Messi is a footballer who plays for Argentina.'

# %%
prompt = PromptTemplate(
    input_variables=["cusine"],
    template="Can you tell me food items for a  {cusine} restuarant"
)

# %%
chain = LLMChain(llm=HuggingFaceHub(repo_id='google/flan-t5-large', model_kwargs={'temperature':0, 'max_length':64}),prompt = prompt)

# %%
chain.run("indian")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
# 'Vegetables'

# %% [markdown]
# <span style="color: red; font-size: 30px; font-weight: bold; background-color: yellow;">
# Approach 1: Text Generation Models | Decoder Only Models
# </span>

# %%
prompt = PromptTemplate(
    input_variables=["name"],
    template="Can you tell me about famous footballer {name}"
)

# %%
chain = LLMChain(llm=HuggingFaceHub(repo_id='mistralai/Mistral-7B-Instruct-v0.3', model_kwargs={'temperature':0.1, 'max_length':64}),prompt = prompt)

# %%
chain.run("Messi")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'post' (from 'huggingface_hub.inference._client') is deprecated and will be removed from version '0.31.0'. Making direct POST requests to the inference server is not supported anymore. Please use task methods instead (e.g. `InferenceClient.chat_completion`). If your use case is not supported, please open an issue in https://github.com/huggingface/huggingface_hub.
#   warnings.warn(warning_message, FutureWarning)
# ...

# %% [markdown]
# <span style="color: red; font-size: 30px; font-weight: bold; background-color: yellow;">
# 5. Approach 2: Download Model Locally ( Create Pipelines)
#
#     Import All the required Libraires
# </span>

# %%
from langchain.llms import HuggingFacePipeline 
import torch 
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline, AutoModelForSeq2SeqLM

# %%
model_id = 'facebook/m2m100_418M'

# %%
tokenizer = AutoTokenizer.from_pretrained(model_id)
# Out:
# tokenizer_config.json:   0%|          | 0.00/298 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/908 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/3.71M [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/1.14k [00:00<?, ?B/s]

# %%
model = AutoModelForSeq2SeqLM.from_pretrained(model_id, load_in_8bit=True, device_map='auto')
# Out:
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# pytorch_model.bin:   0%|          | 0.00/1.94G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/233 [00:00<?, ?B/s]

# %%
model = pipeline("text2text-generation",model=model, tokenizer=tokenizer, max_length=128)
# Out:
# Device set to use cuda:0

# %%
local_llm = HuggingFacePipeline(pipeline = pipeline)

# %%
prompt = PromptTemplate(
    input_variables=["product"],
    template="What is a good name for a company that makes {product}"
)

# %%
chain = LLMChain(llm=local_llm,prompt = [prompt])
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# <ipython-input-42-5d25a5a142f2> in <cell line: 1>()
# ----> 1 chain = LLMChain(llm=local_llm,prompt = [prompt])
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warn_if_direct_instance(self, *args, **kwargs)
#     212                         warned = True
#     213                         emit_warning()
# --> 214                     return wrapped(self, *args, **kwargs)
#     215
#     216                 obj.__init__ = functools.wraps(obj.__init__)(  # type: ignore[misc]
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/load/serializable.py in __init__(self, *args, **kwargs)
#     123     def __init__(self, *args: Any, **kwargs: Any) -> None:
#     124         """"""
# --> 125         super().__init__(*args, **kwargs)
#     126
#     127     @classmethod
#
# ...

# %%
chain.run("colorful socks")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-50b28d707c1c> in <cell line: 1>()
# ----> 1 chain.run("colorful socks")
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     179                 warned = True
#     180                 emit_warning()
# --> 181             return wrapped(*args, **kwargs)
#     182
#     183         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     604             if len(args) != 1:
#     605                 raise ValueError("`run` supports only one positional argument.")
# --> 606             return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     607                 _output_key
# ...

# %%
prompt = PromptTemplate(
    input_variables=["name"],
    template="Can you tell me about famous footballer {name}"
)

# %%
chain = LLMChain(llm=local_llm,prompt = prompt)

# %%
chain.run("Messi")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-c7c52dc3b7a3> in <cell line: 1>()
# ----> 1 chain.run("Messi")
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     179                 warned = True
#     180                 emit_warning()
# --> 181             return wrapped(*args, **kwargs)
#     182
#     183         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     604             if len(args) != 1:
#     605                 raise ValueError("`run` supports only one positional argument.")
# --> 606             return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     607                 _output_key
# ...
